# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from LoadData import load_data

# %%
dirname = os.getcwd()
pth = os.path.join(dirname, 'CMAPSSData')

print('loading data...')
dc = load_data(pth)
print('done')
# Out:
# loading data...
# done

# %%
# get the first data set training data
df = dc['FD_001']['df_train'].copy()

# %%
# get the time of the last available measurement for each unit
mapper = {}
for unit_nr in df['unit_nr'].unique():
    mapper[unit_nr] = df['time'].loc[df['unit_nr'] == unit_nr].max()
    
# calculate RUL = time.max() - time_now for each unit
df['RUL'] = df['unit_nr'].apply(lambda nr: mapper[nr]) - df['time']

# %%
cols_nan = df.columns[df.isna().any()].tolist()
print('Columns with all nan: \n' + str(cols_nan) + '\n')

cols_const = [ col for col in df.columns if len(df[col].unique()) <= 2 ]
print('Columns with all const values: \n' + str(cols_const) + '\n')
# Out:
# Columns with all nan:
# ['sensor_22', 'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26']
#
# Columns with all const values:
# ['os_3', 'sensor_01', 'sensor_05', 'sensor_06', 'sensor_10', 'sensor_16', 'sensor_18', 'sensor_19', 'sensor_22', 'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26']

# %%
df = df.drop(columns=cols_const + cols_nan)

# %%
length = [(nr, d.RUL.max()) for nr, d in df.groupby('unit_nr')]
#plt.plot(df.unit_nr.unique(), length)
plt.plot(df.unit_nr.unique()[60:70], length[60:70])
print()

# %%
df_sub = None

for nr, d in df.groupby('unit_nr'):
    if df_sub is None or d.RUL.max() > df_sub.RUL.max():
        df_sub = d

df_sub = df_sub.set_index('time')

# %%
_ = df_sub.plot(subplots=True, figsize=(15,15))

# %%
df_sub2 = df_sub[[c for c in df_sub.columns if c.startswith('s')]]
_ = df_sub2.plot(subplots=True, figsize=(15,15))

# %%
def rolling_mean(df, n):
    cols_sensors = [c for c in df.columns if c.startswith('sensor')]
    df_new = pd.DataFrame(columns=df.columns)
    
    for nr, d in df.groupby('unit_nr'):
        d.loc[:,cols_sensors] = d[cols_sensors].rolling(n, min_periods=1).mean()
        df_new.append(d)
    return df_new


d = rolling_mean(df, 10)
    
fig, axes = plt.subplots(len(d.columns), 1, figsize=(15,15))
axes = axes.flatten()
for ax, col in zip(axes, df_sub2.columns):
    ax.plot(d.index, d[col].values, linestyle='--')
    ax.plot(df.index, df[col].values)

# %%
def rolling_mean(df, n):
    cols_sensors = [c for c in df.columns if c.startswith('sensor')]
    df_new = pd.DataFrame(columns=df.columns)
    
    for nr, d in df.groupby('unit_nr'):
        d[cols_sensors] = d[cols_sensors].rolling(n, min_periods=1).mean()
        df_new.append(d)
    return df_new


d = rolling_mean(df_sub2, 10)


#for col in df_sub2.columns:
#    print('{}: {}'.format(col, d[col].head(10).unique()))
    
fig, axes = plt.subplots(len(df_sub2.columns), 1, figsize=(15,15))
axes = axes.flatten()
for ax, col in zip(axes, df_sub2.columns):
    ax.plot(d.index, d[col].values, linestyle='--')
    ax.plot(df_sub2.index, df_sub2[col].values, linestyle='--')

# %%
d = df_sub2.rolling(10).mean()

fig, axes = plt.subplots(len(df_sub2.columns), 1, figsize=(15,15))
axes = axes.flatten()
for ax, col in zip(axes, df_sub2.columns):
    ax.plot(d.index, d[col].values, linestyle='--')
    ax.plot(df_sub2.index, df_sub2[col].values, linestyle='--')

# %%
mean = df_sub2.mean()
std = df_sub2.std()

dd = (df_sub2 - mean) / std
dd = (dd).round()
ddd = dd.round().rolling(10).mean()
#ddd = dd.rolling(10).mean()

fig, axes = plt.subplots(len(df_sub2.columns), 1, figsize=(15,15))
axes = axes.flatten()
for ax, col in zip(axes, df_sub2.columns):
    ax.plot(ddd.index, ddd[col].values)
    ax.plot(dd.index, dd[col].values, linestyle='--')

# %%
def fit_line(y):
    dx = len(y)
    x = np.arange(dx)
    A = np.vstack([x, np.ones(len(x))]).T
    m, c = np.linalg.lstsq(A, y, rcond=None)[0]
    return m

dd = d.rolling(100).apply(lambda y: fit_line(y))

_ = dd.plot(subplots=True, figsize=(15,15))
# Out:
# C:\Users\GLA_A\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning

# %%
d = df_sub2.rolling(10).var()
_ = d.plot(figsize=(15,15), subplots=True)
